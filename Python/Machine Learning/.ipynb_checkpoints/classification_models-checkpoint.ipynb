# %% [markdown]
# # Classical Machine Learning - Classification Models

# %% [markdown]
# #### Import necessary dependencies

# %%
import numpy as np

import sklearn
import sklearn.datasets as ds
    # Needed for generating datasets
from sklearn import metrics

import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Creating fake data

# %%
rand_state = np.random.RandomState() 

X, y = ds.make_classification(n_samples=1000, n_features=2,
                              n_repeated=0, class_sep=1,
                              n_redundant=0, random_state=rand_state)
X[:,0] -= min(X[:,0])
X[:,1] -= min(X[:,1])
X[:,1] *= 5

# %%
# plot data
plot = sns.scatterplot(x=X[:,0], y=X[:,1], hue=y)

plt.title('Customer used discount coupon to make purchase')
plt.xlabel('Reminder emails sent')
plt.ylabel('Discount (%)')
plt.show()

# %%
from sklearn.model_selection import train_test_split

# split data into training and testing
X_train, X_test, y_train, y_test = train_test_split(
        X, y, test_size=0.2)

# %% [markdown]
# ## Logistic regression

# %%
from sklearn.linear_model import LogisticRegression

# Instantiate linear regression model
lr = LogisticRegression()

#Train the model using the training sets
lr.fit(X_train, y_train)

#Predict the response for test dataset
y_pred = lr.predict(X_test)

# Model Accuracy, how often is the classifier correct?
print("Logistic Regression Accuracy:", metrics.accuracy_score(y_test, y_pred))
# Out:
# Logistic Regression Accuracy: 0.96

# %% [markdown]
# ## Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier

# Instantiate dt
dt = DecisionTreeClassifier(
    max_depth=6,
    random_state=3)

#Train the model using the training sets
dt.fit(X_train, y_train)

#Predict the response for test dataset
y_pred = dt.predict(X_test)

# Model Accuracy, how often is the classifier correct?
print("Decision Tree Accuracy:", metrics.accuracy_score(y_test, y_pred))
# Out:
# Decision Tree Accuracy: 0.935

# %% [markdown]
# ## Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# Instantiate dt
rf = RandomForestClassifier(
    max_depth=6,
    random_state=3)

#Train the model using the training sets
rf.fit(X_train, y_train)

#Predict the response for test dataset
y_pred = rf.predict(X_test)

# Model Accuracy, how often is the classifier correct?
print("Random Forest Accuracy:", metrics.accuracy_score(y_test, y_pred))
# Out:
# Random Forest Accuracy: 0.94

# %% [markdown]
# ## KNNs (K-nearest neighbors)

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors=9)

#Train the model using the training sets
knn.fit(X_train, y_train)

#Predict the response for test dataset
y_pred = knn.predict(X_test)

# Model Accuracy, how often is the classifier correct?
print("KNN Accuracy:", metrics.accuracy_score(y_test, y_pred))
# Out:
# KNN Accuracy: 0.935

# %% [markdown]
# ## SVM (Support Vector Machines)

# %%
from sklearn.svm import SVC

svc = SVC()

#Train the model using the training sets
svc.fit(X_train, y_train)

#Predict the response for test dataset
y_pred = svc.predict(X_test)

# Model Accuracy, how often is the classifier correct?
print("SVC Accuracy:", metrics.accuracy_score(y_test, y_pred))
# Out:
# SVC Accuracy: 0.955

# %% [markdown]
# ## Comparing Models' RMSE

# %% [markdown]
# Which model is the best highly depends two things: the parameter class_sep during data creation. The more separated the data from the two classes are, the better logistic regression and SVC does. The second being the hyperparameters, for example, the number of neighbors used in the KNN algorithm can greatly change accuracy. Below are two different list of accuracies and below them are the two graphs of data.
#
# Accuracy w/ class_sep=0.1:
#   * Logistic Regresssion: 0.64
#   * Decision Tree: 0.735
#   * Random Forest: 0.84
#   * KNN: 0.79
#   * SVC: 0.64
#
# Accuracy w/ class_sep=1:
#   * Logistic Regresssion: 0.96
#   * Decision Tree: 0.935
#   * Random Forest: 0.94
#   * KNN: 0.935
#   * SVC: 0.955
#
# Assuming the hyperparameters are (nearly) optimal, it seems the label of 'best' classifier depends on class data separation. If the data is fairly separated, and there are only two classes, logistic regression is the way to go. If there are more than two, then you choosing SVC looks 'best'. If the classes are not all that separated, then it seems Random Forests are the best choice. Now, it does seem that there are more hyperparameters to choose with Random Forests when compared to KNNs, so that could sway the decision if there is little time to train hyperparameters. There are probably also other reasons to choose one or the other, but with these datasets, this is my conclusion.

# %%
plot = sns.scatterplot(x=X[:,0], y=X[:,1], hue=y)

plt.title('class_sep=0.1')
plt.xlabel('Reminder emails sent')
plt.ylabel('Discount (%)')
plt.show()

# %%
plot = sns.scatterplot(x=X[:,0], y=X[:,1], hue=y)

plt.title('class_sep=1')
plt.xlabel('Reminder emails sent')
plt.ylabel('Discount (%)')
plt.show()
